# %% [markdown]
# # Liberaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from sklearn.feature_selection import VarianceThreshold, SelectFromModel, SelectKBest, f_classif
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
path = r'I:\Python\dataSet\ml\ercot electricity\ERCOT_dataset.csv'
main_data = pd.read_csv(path)
df = main_data.copy()
df.head(3)
# Out:
#      Date        ERCOT  NG1:COM  NGEU:COM  BTCUSD:CUR  TSLA:US  CL1:COM  \
# 0  4/8/24  43277.56926     1.86     29.60    71703.00   172.98    86.43
# 1  4/5/24  43223.97195     1.79     28.20    67638.37   164.90    86.91
# 2  4/4/24  43286.15326     1.77     27.78    67952.00   171.11    86.59
#
#    UXA:COM  RIVN:US      CPI  ...  USAENEINF  FDTR  UNITEDSTACRUOILPRO  \
# 0    88.75    10.44  312.332  ...      2.121   5.5               12533
# 1    90.74    10.10  312.332  ...      2.121   5.5               12533
# 2    90.90    10.13  312.332  ...      2.121   5.5               12533
#
#    UNITEDSTAOILEXP  WIND:IND  SOLAR:IND  NUCLEAR:IND  TMAX  TMIN  TAVG
# 0        10355.144     15.44      43.74        30.92    79    55    67
# 1        10355.144     15.29      43.13        30.54    84    46    65
# 2        10355.144     15.28      43.72        30.21    72    46    59
#
# [3 rows x 21 columns]

# %%
df['ERCOT'].iloc[:10]
# Out:
# 0    43277.56926
# 1    43223.97195
# 2    43286.15326
# 3    43259.42649
# 4    43167.79365
# 5    44184.34560
# 6    42889.68700
# 7    43206.89016
# 8    43002.28600
# 9    42795.19342
# Name: ERCOT, dtype: float64

# %%
df.shape
# Out:
# (1276, 21)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # DataTypes and Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                1276 non-null   object
#  1   ERCOT               1276 non-null   float64
#  2   NG1:COM             1276 non-null   float64
#  3   NGEU:COM            1276 non-null   float64
#  4   BTCUSD:CUR          1276 non-null   float64
#  5   TSLA:US             1276 non-null   float64
#  6   CL1:COM             1276 non-null   float64
#  7   UXA:COM             1276 non-null   float64
#  8   RIVN:US             1276 non-null   float64
#  9   CPI                 1276 non-null   float64
#  10  CO2E.KT             1276 non-null   float64
#  11  USAENEINF           1276 non-null   float64
#  12  FDTR                1276 non-null   float64
#  13  UNITEDSTACRUOILPRO  1276 non-null   int64
#  14  UNITEDSTAOILEXP     1276 non-null   float64
#  15  WIND:IND            1276 non-null   float64
#  16  SOLAR:IND           1276 non-null   float64
#  17  NUCLEAR:IND         1276 non-null   float64
#  18  TMAX                1276 non-null   int64
#  19  TMIN                1276 non-null   int64
#  20  TAVG                1276 non-null   int64
# dtypes: float64(16), int64(4), object(1)
# memory usage: 209.5+ KB

# %% [markdown]
# # Statistical Information

# %%
round(df.describe(),1)
# Out:
#          ERCOT  NG1:COM  NGEU:COM  BTCUSD:CUR  TSLA:US  CL1:COM  UXA:COM  \
# count   1276.0   1276.0    1276.0      1276.0   1276.0   1276.0   1276.0
# mean   47430.6      3.5      53.2     27567.7    180.6     68.0     43.7
# std     8090.1      1.9      55.7     16774.0    100.4     19.9     17.9
# min    34247.4      1.4       3.7      4850.0     14.9    -37.6     23.8
# 25%    41023.7      2.3      14.8     10838.9     82.6     55.6     29.6
# 50%    45453.8      2.7      31.3     25937.7    201.8     70.9     43.9
# 75%    52966.2      4.1      78.5     40167.7    251.3     80.6     51.6
# max    71634.6      9.7     359.6     73157.0    410.0    119.6    106.0
#
#        RIVN:US     CPI    CO2E.KT  USAENEINF    FDTR  UNITEDSTACRUOILPRO  \
# count   1276.0  1276.0     1276.0     1276.0  1276.0              1276.0
# mean      55.7   279.9  4858055.3        6.5     2.2             11923.0
# std       29.2    20.1   173374.6       16.3     2.1               852.0
# min       10.1   255.5  4715691.1      -18.9     0.2              9773.0
# 25%       24.5   259.1  4752079.3       -5.7     0.2             11307.0
# 50%       78.0   276.6  4792247.3       -0.5     1.8             12010.0
# 75%       78.0   299.2  4908971.4       24.5     4.5             12662.0
# max      172.0   312.3  5259143.8       41.6     5.5             13315.0
#
#        UNITEDSTAOILEXP  WIND:IND  SOLAR:IND  NUCLEAR:IND    TMAX    TMIN  \
# count           1276.0    1276.0     1276.0       1276.0  1276.0  1276.0
# mean            7184.6      17.3       62.2         18.8    78.8    55.9
# std             2561.8       3.1       23.4          6.3    16.9    16.7
# min             2746.7      10.2       22.2          7.1    24.0    10.0
# 25%             5042.4      14.8       41.9         11.6    67.0    42.0
# 50%             6722.7      17.3       69.2         19.9    80.5    57.0
# 75%             9468.5      19.5       79.2         23.1    92.0    71.0
# max            11664.0      26.0      121.9         32.2   112.0    84.0
#
#          TAVG
# count  1276.0
# mean     67.6
# std      16.3
# min      17.0
# 25%      55.0
# 50%      69.0
# 75%      82.0
# max      98.0

# %%
df.set_index('Date', inplace=True)

# %% [markdown]
# # Distribution of Data

# %%
df.hist(figsize=(10,15))
plt.show()

# %%
def check_normal_distribution(df):
    plt.figure(figsize=(16, 12))
    for i in range(df.shape[1]):
        plt.subplot(5, 4, i+1)
        stats.probplot(df.iloc[:, i], dist="norm", plot=plt)
        plt.title(df.columns[i])
        plt.tight_layout()
        plt.grid(True)
    plt.show()

# %%
def plot_normal_distribution(df):
    plt.figure(figsize=(16, 12))
    for i in range(df.shape[1]):
        plt.subplot(5, 4, i+1)
        sns.distplot(df.iloc[:, i], hist=False, kde = True,
                     kde_kws = {'shade': True, 'linewidth': 2}, label = df.columns[i], color ="green")
        plt.tight_layout()
        plt.grid(True)

# %%
plot_normal_distribution(df)

# %%
check_normal_distribution(df)

# %%
def check_normal_distribution_skew(df):
    normal = []
    right_skew = []
    left_skew = []
    for i in range(df.shape[1]):
        skew = df.skew()
        if (-0.5 < X_train.skew()[i] < 0.5):
            normal.append(df[skew.index])
            print(f'The Distribution of the {df.columns[i]} is Normal Distribution')
        elif (i > 1) | (0.5 < i < 1):
            right_skew.append(df[skew.index])
            print(f'The Distribution of the {df.columns[i]} is Right Skew')     
        elif (i < -1) | (-0.5 < i < -1):
            left_skew.append(df[skew.index])
            print(f'The Distribution of the {df.columns[i]} is Left Skew')         
    return normal, right_skew, left_skew

# %%
normal, right_skew, left_skew = check_normal_distribution_skew(df.drop('ERCOT', axis=1))
# Out:
# The Distribution of the BTCUSD:CUR is Normal Distribution
# The Distribution of the TSLA:US is Normal Distribution
# The Distribution of the CL1:COM is Right Skew
# The Distribution of the UXA:COM is Right Skew
# The Distribution of the RIVN:US is Normal Distribution
# The Distribution of the CPI is Normal Distribution
# The Distribution of the CO2E.KT is Normal Distribution
# The Distribution of the USAENEINF is Right Skew
# The Distribution of the FDTR is Right Skew
# The Distribution of the UNITEDSTACRUOILPRO is Normal Distribution
# The Distribution of the UNITEDSTAOILEXP is Normal Distribution
# The Distribution of the WIND:IND is Normal Distribution
# The Distribution of the SOLAR:IND is Normal Distribution
# The Distribution of the NUCLEAR:IND is Normal Distribution
# The Distribution of the TMAX is Normal Distribution
# The Distribution of the TMIN is Normal Distribution
# The Distribution of the TAVG is Normal Distribution

# %% [markdown]
# # Feature Cleaning

# %% [markdown]
# # Missing Values

# %%
df.isna().sum()
# Out:
# ERCOT                 0
# NG1:COM               0
# NGEU:COM              0
# BTCUSD:CUR            0
# TSLA:US               0
# CL1:COM               0
# UXA:COM               0
# RIVN:US               0
# CPI                   0
# CO2E.KT               0
# USAENEINF             0
# FDTR                  0
# UNITEDSTACRUOILPRO    0
# UNITEDSTAOILEXP       0
# WIND:IND              0
# SOLAR:IND             0
# NUCLEAR:IND           0
# TMAX                  0
# TMIN                  0
# TAVG                  0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
def find_outliers_boxplot(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df = df.select_dtypes(include = numerics)
    plt.figure(figsize=(12, 12))
    for i in range(df.shape[1]):
        plt.subplot(5, 4, i+1)
        sns.boxplot(data=df, y=df.columns[i])
        plt.xlabel(df.columns[i])
        plt.tight_layout()
        plt.grid(True)

# %%
def find_outliers(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df = df.select_dtypes(include = numerics)
    for i in df.columns:
        Q1 = np.percentile(df[i], 25)
        Q3 = np.percentile(df[i], 75)
        IQR = Q3 - Q1
        upper = Q3 + (1.5*IQR)
        lower = Q1 - (1.5*IQR)

        inliers = df[i].ge(lower)
        df = df.loc[inliers]

        inliers = df[i].le(upper)
        df = df.loc[inliers]   
    return df

# %%
find_outliers_boxplot(df)

# %%
df = find_outliers(df)

# %%
df.shape
# Out:
# (752, 20)

# %% [markdown]
# # Split Data

# %%
X_train, X_test , y_train, y_test = train_test_split(df.drop('ERCOT', axis=1), df['ERCOT'], test_size=0.2, random_state=24)

# %% [markdown]
# # Feature Selection

# %%
X_train.shape, X_test.shape
# Out:
# ((601, 19), (151, 19))

# %% [markdown]
# # Constant Features

# %%
selection_constant = VarianceThreshold(threshold = 0)
selection_constant.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
X_train_constant = selection_constant.transform(X_train)
X_test_constant = selection_constant.transform(X_test)
X_train_constant.shape, X_test_constant.shape
# Out:
# ((601, 19), (151, 19))

# %% [markdown]
# # threshold = 0.01

# %%
selection = VarianceThreshold(threshold = 0.01)
selection.fit(X_train)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
concol = [column for column in X_train.columns 
          if column not in X_train.columns[selection.get_support()]]
concol
# Out:
# []

# %%
X_train_t = selection.transform(X_train)
X_test_t = selection.transform(X_test)
X_train_t = pd.DataFrame(X_train_t, columns=selection.get_feature_names_out())
X_test_t = pd.DataFrame(X_test_t, columns=selection.get_feature_names_out())

# %%
X_train_t.shape, X_test_t.shape
# Out:
# ((601, 19), (151, 19))

# %% [markdown]
# # Correlation

# %%
# the default correlation method of pandas.corr is pearson
cor = X_train.corr(method='pearson')
# To modify image size
fig, ax = plt.subplots()
fig.set_size_inches(16, 8)
# customized color map
cmap = sns.diverging_palette(220, 20, as_cmap=True)
# we can make a heatmap with seaborn
sns.heatmap(cor, cmap=cmap, annot=True)
plt.show()

# %%
def correlation(dataset, threshold):
    # create a set where we store the correlated columns
    col_corr = set()
    # create the correlation matrix
    corr_matrix = dataset.corr()
    # for each feature in the dataset (columns of the correlation matrix)
    for i in range(len(corr_matrix.columns)):
        # check with other features
        for j in range(i):
            # if the correlation is higher than the threshold
            # (we are interested in absolute coeff value)
            if abs(corr_matrix.iloc[i, j]) > threshold:                   
                # get the name of the correlated feature
                colname = corr_matrix.columns[j]
                # and add it to our correlated set
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.9)
corr_features
# Out:
# {'CPI', 'FDTR', 'RIVN:US', 'TMAX', 'TMIN', 'UXA:COM', 'WIND:IND'}

# %%
X_train_correlation = X_train.drop(labels=corr_features, axis=1)
X_test_correlation = X_test.drop(labels=corr_features, axis=1)
X_train_correlation.shape, X_test_correlation.shape
# Out:
# ((601, 12), (151, 12))

# %% [markdown]
# # Correlation Feature vs Group of Features

# %%
corrmat = X_train.corr()
corrmat = corrmat.abs().unstack()
corrmat = corrmat[corrmat > 0.9]
corrmat = corrmat[corrmat < 1]

# %%
corrmat = pd.DataFrame(corrmat).reset_index()
corrmat.columns = ['feature1', 'feature2', 'corr']

grouped_feature_ls = []
correlated_groups = []

for feature in corrmat['feature1'].unique():
    if feature not in grouped_feature_ls:
        # find all features correlated to a single feature
        correlated_block = corrmat[corrmat['feature1'] == feature]
        grouped_feature_ls = grouped_feature_ls + list(
            correlated_block['feature2'].unique()) + [feature]
        # append the block of features to the list
        correlated_groups.append(correlated_block)
print(
    f"Found {len(correlated_groups)} correlated groups from {len(X_train)}  features.")
# Out:
# Found 7 correlated groups from 601  features.

# %%
dt = pd.DataFrame()
for i in range(6):
    dt = pd.concat([dt, correlated_groups[i]])
dt
# Out:
#            feature1   feature2      corr
# 0           UXA:COM        CPI  0.908540
# 1           RIVN:US        CPI  0.901753
# 2           RIVN:US       FDTR  0.959234
# 8           CO2E.KT        CPI  0.955931
# 12  UNITEDSTAOILEXP        CPI  0.920377
# 13  UNITEDSTAOILEXP       FDTR  0.906216
# 14         WIND:IND  SOLAR:IND  0.939685
# 16             TMAX       TAVG  0.969335

# %% [markdown]
# # Select From Model

# %%
sel_ = SelectFromModel(RandomForestRegressor(n_estimators=5, random_state=24))
sel_.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestRegressor(n_estimators=5,
#                                                 random_state=24))

# %%
pd.Series(sel_.estimator_.feature_importances_.ravel(), index=X_train.columns).sort_values(ascending=False).plot.bar(figsize=(10,5))
plt.ylabel('Feature importance')
plt.show()

# %%
X_train_select_from_model = sel_.transform(X_train)
X_test_select_from_model = sel_.transform(X_test)

# %%
X_train_select_from_model.shape, X_test_select_from_model.shape
# Out:
# ((601, 3), (151, 3))

# %% [markdown]
# # Mutual Information by Calculating Information Gain

# %%
mutual = mutual_info_regression(X_train, y_train)
feature_mutual = pd.Series(mutual, X_train.columns[0:len(X_train.columns)]).sort_values(ascending=False)
feature_mutual.plot(kind='bar', color='teal')
plt.show()

# %%
X_train_mutual = X_train[feature_mutual[:11].index]
X_test_mutual = X_test[feature_mutual[:11].index]

# %%
X_test_mutual.head()
# Out:
#           UNITEDSTACRUOILPRO  TAVG  UXA:COM  TMIN  UNITEDSTAOILEXP      CPI  \
# Date
# 5/13/21                11230    58    30.95    54         5551.946  269.195
# 9/22/23                13053    86    60.42    76        10249.635  307.789
# 10/23/20               10870    75    29.25    63         4064.890  260.388
# 2/7/23                 12462    66    50.65    57         8585.588  300.840
# 6/17/21                11312    85    32.40    74         5359.621  271.696
#
#           USAENEINF  TMAX  NGEU:COM  BTCUSD:CUR  SOLAR:IND
# Date
# 5/13/21      28.547    61     27.83    49675.20      69.10
# 9/22/23      -0.450    96     42.18    26542.13      52.82
# 10/23/20     -9.195    87     16.17    12939.00      71.12
# 2/7/23        5.200    75     58.73    23197.00      78.92
# 6/17/21      24.481    96     30.01    38078.20      83.10

# %% [markdown]
# # Feature Scaling

# %%
scaler = MinMaxScaler().set_output(transform="pandas")
scaler.fit(X_train_mutual)
# Out:
# MinMaxScaler()

# %%
X_train_mutual_scaling = scaler.transform(X_train_mutual)
X_test_mutual_scaling = scaler.transform(X_test_mutual)

# %%
X_train_mutual_scaling.shape, y_train.shape
# Out:
# ((601, 11), (601,))

# %% [markdown]
# # Linear Model

# %%
s = MinMaxScaler().set_output(transform="pandas")
s.fit(X_train)
x = s.transform(X_train)
xs = s.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train_mutual_scaling, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_mutual_scaling)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 32039166.709939077
# R-squared (R2): 0.631192956744974

# %% [markdown]
# * We have very small data so we expected that Score

# %% [markdown]
# # RandomForest Model

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=1000, max_depth=4, random_state=24)
RandomForestRegressorModel.fit(X_train_mutual_scaling, y_train)
#Calculating Prediction
y_pred_rf = RandomForestRegressorModel.predict(X_test_mutual_scaling)

# %%
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Mean Squared Error (MSE):", mse_rf)
print("R-squared (R2):", r2_rf)
# Out:
# Mean Squared Error (MSE): 8697591.352351341
# R-squared (R2): 0.8998808870673254

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
plot_tree(RandomForestRegressorModel.estimators_[0],feature_names= list(X_train_mutual_scaling.columns), filled=True)
plt.show()

# %% [markdown]
# # Using Pickle on Model for convert it to Api

# %%
import pickle

# %%
# Serialize model to a file using pickle
with open('ERCOT_Electricity_model.pkl', 'wb') as model_file:
    pickle.dump((RandomForestRegressorModel, scaler), model_file)

# %%
with open('ERCOT_Electricity_model.pkl', 'rb') as model_file:
    model_pickle, scaler_loading = pickle.load(model_file)

# %%
X_train_mutual.columns
# Out:
# Index(['UNITEDSTACRUOILPRO', 'TAVG', 'UXA:COM', 'TMIN', 'UNITEDSTAOILEXP',
#        'CPI', 'USAENEINF', 'TMAX', 'NGEU:COM', 'BTCUSD:CUR', 'SOLAR:IND'],
#       dtype='object')

# %%
data_test = {'UNITEDSTACRUOILPRO':[11230],'TAVG':[58],'UXA:COM':[30.95],
             'TMIN':[54],'UNITEDSTAOILEXP':[5551.946],'CPI':[269.195],'USAENEINF':[28.547],'TMAX':[61],
             'NGEU:COM':[27.83],'BTCUSD:CUR':[49675.20],'SOLAR:IND':[69.10]}
dff = pd.DataFrame(data_test)
model_pickle.predict(scaler_loading.transform(dff))
# Out:
# array([40075.87208596])
